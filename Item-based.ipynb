# %%
#데이터 조작을 위한 모듈
import pandas as pd

#모델을 만들기 위한 모듈
from surprise import KNNBasic
from surprise import Reader
from surprise import Dataset
from surprise import accuracy
from surprise.model_selection import KFold
from surprise.model_selection import GridSearchCV
import pickle

# %%
param_grid = {'k': [7,8,9,10], 'min_k': [0.002, 0.005]} # GridSearchCV로 최적의 parameter 구해줌
gs = GridSearchCV(KNNBasic, param_grid, measures=['rmse', 'mae'], cv=5)

gs.fit(data)

# best RMSE score
print(gs.best_score['rmse'])

# combination of parameters that gave the best RMSE score
print(gs.best_params['rmse'])
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# ...

# %%
#평점 데이터를 서프라이즈에 맞추는 reader 객체를 만든다.
reader=Reader(line_format=u'user item rating',sep=",", rating_scale=(0.0,5.0))

rating_df=pd.read_csv("./database/ratings.csv")

product_meta=pd.read_csv("./database/products.csv")
product_meta=product_meta[["product_id","product_name"]].copy()

user_meta=pd.read_csv("./database/users.csv")
user_meta=user_meta[["user_id","nickname"]].copy()

data = Dataset.load_from_df(rating_df, reader=reader)

sim_options={"user_based":False,
             "name":"pearson"}
algo=KNNBasic(k=8,min_k=0.002)

# %%
# 교차검증 횟수를 지정한다.
kf = KFold(n_splits=5)

for trainset, testset in kf.split(data):

    # train and test algorithm.
    algo.fit(trainset)
    predictions = algo.test(testset)

    # Compute and print Root Mean Squared Error
    print(accuracy.rmse(predictions, verbose=True))


trainset=data.build_full_trainset()
algo.fit(trainset)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.0826
# 1.0825506858491205
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.0404
# 1.0403985553810693
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.0691
# 1.069147509314238
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.0806
# 1.0805841185694849
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.0499
# 1.0499255448990006
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %%
pickle.dump(algo, open("recomm.pkl", "wb"))
print("model saved!")
